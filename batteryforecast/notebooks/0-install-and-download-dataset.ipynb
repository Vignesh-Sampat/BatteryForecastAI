# %% [markdown]
# # Installation and Dataset Setup
#
# We will clone the repository, install the necessary requirements, and set up a folder to download the raw dataset.
#
# ## Step 1: Cloning the Repository and Installing Requirements
#
# First, we will clone the BatteryForecastAI repository from GitHub and install the required Python packages. Run the following commands:

# %%
# !git clone https://github.com/Vignesh-Sampat/BatteryForecastAI
# %cd BatteryForecastAI
# !pip install -r requirements.txt -q
# Out:
# Cloning into 'BatteryForecastAI'...
# remote: Enumerating objects: 107, done.
# remote: Counting objects: 100% (107/107), done.
# remote: Compressing objects: 100% (71/71), done.
# remote: Total 107 (delta 38), reused 97 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (107/107), 422.82 KiB | 14.09 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# /kaggle/working/BatteryForecastAI
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# beatrix-jupyterlab 2024.66.154055 requires jupyterlab~=3.6.0, but you have jupyterlab 4.2.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-bigquery[bqstorage,pandas]>=3.10.0, but you have google-cloud-bigquery 2.34.4 which is incompatible.
# bigframes 0.22.0 requires google-cloud-storage>=2.0.0, but you have google-cloud-storage 1.44.0 which is incompatible.
# ...

# %% [markdown]
# ## Step 2: Creating a Folder for the Raw Dataset
# Next, we will create a directory where we will download the raw dataset. You can choose to download specific datasets such as CAMP, SEVERSON, or ALL. In this example, we will download the CAMP dataset.
#
# Run the following commands to create the folder and download the dataset:

# %%
# !mkdir dataset
# !python batteryforecast/data/download.py CAMP dataset
# Out:
# 100%|█████████████████████████████████████████████| 3/3 [00:06<00:00,  2.16s/it]

# %%
# !ls dataset
# Out:
# batch_B10A_cell_3.h5  batch_B11B_cell_4.h5
# batch_B10A_cell_4.h5  combined_data.csv
